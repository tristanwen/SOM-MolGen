# %%
import numpy as np
import pandas as pd
from fragments2mol import *
from test_fp_similarity import *

# %%
# metic_dict = {0: 'DataStructs.TanimotoSimilarity',
#               1: 'DataStructs.DiceSimilarity',
#               2: 'DataStructs.CosineSimilarity',
#               3: 'DataStructs.SokalSimilarity',
#               4: 'DataStructs.RusselSimilarity',
#               5: 'DataStructs.KulczynskiSimilarity',
#               6: 'DataStructs.McConnaugheySimilarity',
#               7: 'DataStructs.RogotGoldbergSimilarity',
#               8: 'DataStructs.AllBitSimilarity',
#               9: 'DataStructs.AsymmetricSimilarity',
#               10: 'DataStructs.BraunBlanquetSimilarity'}
# ALL_fp_type = {'MACCSkey': my_fp_cal.MACCSkey(),
#                'RDKitTopological': my_fp_cal.RDKitTopological(fpSize=fpSize),
#                'Morgan': my_fp_cal.Morgan(radius=radius, fpSize=fpSize),
#                'Avalon': my_fp_cal.Avalon(fpSize=fpSize)}

# %%
root = "F:\\WORK\\和外合作\\天宇媛媛毕设\\generate\\result3\\"
dataset = pd.read_csv(root+"all_final_new_mols.csv")

# %%
smiles_list = ['S(=O)(=O)(NC(=O)c1ccccc1)c2ccc(OC)cc2',
               'S(=O)(=O)(NC(=O)c1ccccc1)c2ccc(C)cc2',
               'S(=O)(=O)(NC(=O)c1ccc(OC)cc1)c2ccc(C)cc2',
               'c1ccccc1CC(=O)NS(=O)(=O)c2ccccc2',
               'S(=O)(=O)(NC(=O)c1ccccc1)c2ccccc2',
               'S(=O)(=O)(NC(=O)c1ccccc1)c2ccc(Cl)cc2',
               'c1ccc2cccc(NC(=O)CN3CCN(C)CC3)c2c1',
               'S(=O)(=O)(c1ccc(OC)cc1)c2ccc(cc2)C(=O)O',
               'S(=O)(=O)(NC(=O)c1ccc(C)cc1)c2ccc(C)cc2',
               'S(=O)(=O)(NS(=O)(=O)c1ccccc1)c2ccccc2',
               'S(=O)(=O)(Nc1ccc(cc1)S(C)(=O)=O)c2ccc(C)cc2',
               'S(=O)(=O)(NC(=O)OCc1ccccc1)c2ccccc2',
               ]

Similarity_heatmap(smi_list=smiles_list,
                   select_fp_type='Morgan',
                   select_Similarity_index=0)
# Out:
#                                              S(=O)(=O)(NC(=O)c1ccccc1)c2ccc(OC)cc2  \
# S(=O)(=O)(NC(=O)c1ccccc1)c2ccc(OC)cc2                                     1.000000
# S(=O)(=O)(NC(=O)c1ccccc1)c2ccc(C)cc2                                      0.880734
# S(=O)(=O)(NC(=O)c1ccc(OC)cc1)c2ccc(C)cc2                                  0.901786
# c1ccccc1CC(=O)NS(=O)(=O)c2ccccc2                                          0.750000
# S(=O)(=O)(NC(=O)c1ccccc1)c2ccccc2                                         0.884615
# S(=O)(=O)(NC(=O)c1ccccc1)c2ccc(Cl)cc2                                     0.811966
# c1ccc2cccc(NC(=O)CN3CCN(C)CC3)c2c1                                        0.142857
# S(=O)(=O)(c1ccc(OC)cc1)c2ccc(cc2)C(=O)O                                   0.448000
# S(=O)(=O)(NC(=O)c1ccc(C)cc1)c2ccc(C)cc2                                   0.872727
# S(=O)(=O)(NS(=O)(=O)c1ccccc1)c2ccccc2                                     0.690265
# ...

# %%
smiles_list = ['S(=O)(=O)(NC(=O)c1ccccc1)c2ccc(OC)cc2',
               'O=C1C(NC(=O)CCCC)=CC(=O)c2ccccc12',
               'N(C(=O)N1CCCCCC1=O)c2ccccc2OC',
               'C(O)(CN1CCOCC1)c2ccc(Br)cc2',
               'S(=O)(=O)(CS(=O)(=O)c1ccccc1)c2ccccc2',
               'C(CCO)N1CCN(CC1)c2ccc(C)cc2',
               'S(=O)(=O)(N(C)C)c1ccccc1C2(O)CCCCC2',
               'S(=O)(=O)(c1ccc(C)cc1)N(C)c2ccc(N)cc2',
               'O(CC(=O)O)c1c(Br)cc(C)cc1Br',
               'C(N1CCCC1)N2N=C(OC2=O)c3ccc(O)cc3',
               'C(CC(=O)O)N1CCN(CC1)c2ccccc2',
               'C(N1CCCCC1)c2ccc(cc2)NC(C)=O',
               ]
Similarity_heatmap(smi_list=smiles_list,
                   select_fp_type='Morgan',
                   radius=2, fpSize=2048,
                   select_Similarity_index=1)
# Out:
#                                        S(=O)(=O)(NC(=O)c1ccccc1)c2ccc(OC)cc2  \
# S(=O)(=O)(NC(=O)c1ccccc1)c2ccc(OC)cc2                               1.000000
# O=C1C(NC(=O)CCCC)=CC(=O)c2ccccc12                                   0.275556
# N(C(=O)N1CCCCCC1=O)c2ccccc2OC                                       0.281818
# C(O)(CN1CCOCC1)c2ccc(Br)cc2                                         0.177778
# S(=O)(=O)(CS(=O)(=O)c1ccccc1)c2ccccc2                               0.635838
# C(CCO)N1CCN(CC1)c2ccc(C)cc2                                         0.187845
# S(=O)(=O)(N(C)C)c1ccccc1C2(O)CCCCC2                                 0.503759
# S(=O)(=O)(c1ccc(C)cc1)N(C)c2ccc(N)cc2                               0.633484
# O(CC(=O)O)c1c(Br)cc(C)cc1Br                                         0.240964
# C(N1CCCC1)N2N=C(OC2=O)c3ccc(O)cc3                                   0.185464
# C(CC(=O)O)N1CCN(CC1)c2ccccc2                                        0.191011
# ...
